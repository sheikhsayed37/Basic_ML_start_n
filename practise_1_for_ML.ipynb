# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# Task 1:
# Using the pandas functions covered in class, answer the following:
# • What is the total number of samples (rows) and potential features (columns) in this
# dataset?
# • Display the first 7 rows of the dataset to understand the structure.
# • Display a random sample of 5 rows.
# Why might it be better to look at a random sample rather than just the top rows? Answer
# in two lines

# %% [markdown]
# Task 1

# %%
df.shape

print(f"total number of samples (rows) : {df.shape[0]}")
print(f"total number of samples (rows) : {df.shape[1]}")
# Out:
# total number of samples (rows) : 344
# total number of samples (rows) : 7

# %%
df.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %%
#random
df.sample(5)
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 252     Gentoo  Biscoe            45.1           14.5              207.0
# 46      Adelie   Dream            41.1           19.0              182.0
# 205  Chinstrap   Dream            50.7           19.7              203.0
# 56      Adelie  Biscoe            39.0           17.5              186.0
# 170  Chinstrap   Dream            46.4           18.6              190.0
#
#      body_mass_g     sex
# 252       5050.0  Female
# 46        3425.0    Male
# 205       4050.0    Male
# 56        3550.0  Female
# 170       3450.0  Female

# %%
#  A random sample gives a more representative view of the dataset.

#  Top rows may contain ordered or similar data, which might not reflect the overall dataset properly.

# %% [markdown]
# Task 2:
# Before analyzing the data, we must check for missing information.
# • Write the code to calculate the total number of missing values for each column.
# • Which feature contains the highest number of missing values?

# %% [markdown]
# task-2

# %%
df.isnull().sum()   #column e koita missing value seta dekai
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.isnull().sum().max()
# max ta show kortese
# Out:
# 11

# %%
df.isnull().sum().idxmax()
# akne kon index tate missing value beshi seta dakacce
# Out:
# 'sex'

# %% [markdown]
# Task 3:
# Duplicate entries can hamper model performance.
# • Check if there are any duplicate rows in the penguins dataset. How many duplicates are
# there?
# • Write the code to permanently remove any duplicate rows from your DataFrame.

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# Task 4:
# Let's profile the dataset to understand its distributions.
# • Use the appropriate method to print a concise summary of the DataFrame, including the
# data types of each column and non-null counts.
# • Generate a statistical summary for the numerical columns.
# • Based on your statistical summary, what is the maximum body_mass_g of a penguin in
# this dataset? What is the average (mean) flipper_length_mm?

# %% [markdown]
# Task 4

# %%
# Concise summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
# Statistical summary for numerical columns
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# df['body_mass_g'].idxmax() # max ter index
df['body_mass_g'].max()
# Out:
# 6300.0

# %%
df['flipper_length_mm'].mean()
# Out:
# np.float64(200.91520467836258)

# %% [markdown]
# Task 5:
# Create a visualization to understand the distribution of penguin species.
# • Use Seaborn to create a count plot for the species column.
# • Which species is the most common in this dataset?

# %%
sns.countplot(data=df,x='species')

plt.xlabel('species')
plt.ylabel('frequency of count')
plt.title('distribution of penguin species')

plt.show()

# %%
df['species'].value_counts() # values count korte bolece
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# Task 6:
# • Write the code to calculate the percentage distribution of the island column

# %%
(df['island'].value_counts()/len(df))*100
# Out:
# island
# Biscoe       48.837209
# Dream        36.046512
# Torgersen    15.116279
# Name: count, dtype: float64

# %% [markdown]
# Task 7:
# Let's visualize the gender distribution among the surveyed penguins.
# • Extract the value counts for the sex column.
# • Create a pie chart using Matplotlib showing the male vs. female distribution.
# • Ensure the pie chart includes percentage labels with one decimal point (example
# 50.5%).
# Add a title to your chart.

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      168
# Female    165
# Name: count, dtype: int64

# %%
plt.pie(df['sex'].value_counts(),labels=df['sex'].value_counts().index,autopct='%1.1f%%')
plt.title('gender distribution')
plt.show()
